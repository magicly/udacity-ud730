# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5243, 3084, 12, 6, 195, 2, 3136, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'anarchism', 'term', 'a', 'of', 'term', 'originated', 'as']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, train_labels, embed,
                               num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %% [markdown]
# 不明白为什么既有embeddings又有softmax_weights， 感觉不是直接用embeddings计算相似度就可以了么？
# 参考stanford cs224n课程chap2-3， http://web.stanford.edu/class/cs224n/syllabus.html
# ```
# Each word type(vocab entry) has **two** word representations as center word and context word.
# ```
# 所以embeddings是word作为center word的vector，而soft_weights是word作为context word的vector。

# %%
num_steps = 10001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.690428
# Nearest to as: mckay, balto, resulting, anand, perkin, combinatorics, playwrights, syst,
# Nearest to states: progressivism, licensure, aap, snes, fram, hermetic, bysshe, jorge,
# Nearest to during: teller, kindred, brion, asdb, guild, pekka, protectorate, dilation,
# Nearest to some: philological, proclaim, underscores, darts, cinder, turku, octaves, kubitzki,
# Nearest to new: peyton, smtp, brie, gravity, stryker, listed, denoted, vai,
# Nearest to six: interscope, unremarkable, nazareth, pxe, ang, gauss, careers, publicizing,
# Nearest to that: pressurized, outages, propose, roofs, songhai, leftmost, conjectured, wight,
# Nearest to zero: flaws, ordo, experience, auditum, dearly, smokey, invites, hussites,
# Nearest to people: panther, threefold, prompted, mutations, hardy, polo, raced, justifies,
# Nearest to and: coslet, starship, checkers, fulfill, rains, kalat, kennedy, cerberus,
# Nearest to many: spikes, vowel, repetitions, marrying, miraculous, quarterfinals, nawab, rulebase,
# Nearest to into: averages, printers, cools, doherty, switching, corruption, octane, desecration,
# Nearest to will: pilsener, smuggling, codons, ambiguities, faraday, dare, kung, raced,
# Nearest to no: overloaded, anatole, lupin, jass, enterprise, outrage, keyser, lans,
# Nearest to years: choke, suffer, pravda, alligators, monitor, communicative, smyrna, margarine,
# Nearest to state: smack, theremin, sean, lez, andrea, casing, ayling, wicked,
# Average loss at step 2000: 4.374571
# Average loss at step 4000: 3.862288
# Average loss at step 6000: 3.786716
# Average loss at step 8000: 3.688951
# Average loss at step 10000: 3.613534
# Nearest to as: depose, playwrights, rebadged, temair, irredentist, by, storks, bhutan,
# Nearest to states: progressivism, fram, licensure, snes, fatah, obvious, aap, tidings,
# Nearest to during: on, after, canoes, filk, asdb, kames, including, mediterranean,
# Nearest to some: many, these, planes, eccentricity, caracalla, sustenance, superman, wigner,
# Nearest to new: peyton, gravity, stew, smpte, maggots, vai, jadavpur, recount,
# Nearest to six: four, eight, seven, three, five, nine, zero, two,
# Nearest to that: which, usurped, who, ordinary, established, it, they, songhai,
# Nearest to zero: nine, eight, six, seven, four, three, five, two,
# Nearest to people: cpc, prompted, practicality, andy, justifies, delacroix, finiteness, omphalos,
# Nearest to and: or, bowers, who, but, in, d, breathe, b,
# Nearest to many: some, several, spikes, protists, housekeeper, elbe, sinks, trna,
# Nearest to into: from, jdf, immunotherapy, averages, cools, proportional, doughnut, hen,
# Nearest to will: can, may, would, haile, unsatisfied, anthropology, could, pied,
# Nearest to no: it, lupin, succumbed, proven, phenomenological, symbolised, aeolian, neurological,
# Nearest to years: choke, eugenic, repelling, hustler, myoglobin, gran, turnover, reductionist,
# Nearest to state: smack, theremin, tunny, submits, ceded, java, haznawi, relocate,

# %%
num_points = 400
tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000) # ValueError: array must not contain infs or NaNs, refer to: https://github.com/scikit-learn/scikit-learn/issues/6665#issuecomment-264029983
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %% [markdown]
# CBOW跟skip-gram相反，使用context的词来预测当前词，所以训练数据的输入输出刚好交换了。

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return labels.reshape(batch_size), batch.reshape(batch_size, 1)

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch.reshape(8)])
#     print(batch, labels)
    print('    labels:', [reverse_dictionary[li] for li in labels])
    
#     print('    batch:', [[reverse_dictionary[w] for w in bi] for bi in batch])  
#     print('    labels:', [reverse_dictionary[li] for li in labels.reshape(4)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['anarchism', 'as', 'originated', 'a', 'term', 'as', 'a', 'of']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-b8172f6f200b> in <module>()
#      33     print('    batch:', [reverse_dictionary[bi] for bi in batch.reshape(8)])
#      34 #     print(batch, labels)
# ---> 35     print('    labels:', [reverse_dictionary[li] for li in labels])
#      36
#      37 #     print('    batch:', [[reverse_dictionary[w] for w in bi] for bi in batch])
#
# <ipython-input-56-b8172f6f200b> in <listcomp>(.0)
#      33     print('    batch:', [reverse_dictionary[bi] for bi in batch.reshape(8)])
#      34 #     print(batch, labels)
# ---> 35     print('    labels:', [reverse_dictionary[li] for li in labels])
#      36
#      37 #     print('    batch:', [[reverse_dictionary[w] for w in bi] for bi in batch])
#
# TypeError: unhashable type: 'numpy.ndarray'

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, train_labels, embed,
                               num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 10001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.028061
# Nearest to nine: credo, lans, lilian, alton, liquified, ttel, shoemaker, begotten,
# Nearest to during: rubies, puberty, commendation, salinity, aficionados, conductivity, peppard, completing,
# Nearest to as: ratifying, covered, fh, maclisp, humber, pegasus, descriptors, below,
# Nearest to about: dodgson, hampered, gide, instructions, envy, assembler, pinnacle, boyle,
# Nearest to i: featured, revisionism, someday, aqsa, guitarists, lightsabers, ants, friesian,
# Nearest to but: alarmed, buddhism, arousal, themed, mond, iucn, slade, milwaukee,
# Nearest to however: muds, oases, combines, artery, cc, intuition, avenger, wrath,
# Nearest to many: trie, chewed, creeping, nitrogen, ensuing, sw, jonah, verdicts,
# Nearest to if: demiurge, dyess, exploiting, manuscripts, inference, jh, siddur, lawyers,
# Nearest to three: quranic, hosea, assassins, extrapolation, ultima, lose, iic, affliction,
# Nearest to on: chomsky, autonegotiation, attitude, electrolysis, soon, propulsion, catalyzed, manifested,
# Nearest to into: ironically, chair, kingdoms, unit, furs, sarin, highway, analogue,
# Nearest to after: specie, implantation, ski, banners, projections, introductory, coptic, alphorn,
# Nearest to at: postponed, rda, lammas, inherit, alexandrians, mephisto, acf, tobruk,
# Nearest to system: mapsto, tatra, saviola, friesland, hc, modulated, patenting, salts,
# Nearest to UNK: revitalized, tunic, maronite, ganga, advisable, floats, rheingold, flamsteed,
# Average loss at step 2000: 4.371125
# Average loss at step 4000: 3.859419
# Average loss at step 6000: 3.788752
# Average loss at step 8000: 3.687883
# Average loss at step 10000: 3.617392
# Nearest to nine: eight, seven, six, five, zero, three, four, two,
# Nearest to during: linguistic, in, conductivity, msnbc, peppard, air, inductively, album,
# Nearest to as: agonists, interpolant, by, habits, zug, mountainous, brine, tetragrammaton,
# Nearest to about: fh, just, gide, hampered, pinnacle, garde, amplify, brent,
# Nearest to i: guitarists, hierarchical, ushered, appeals, euphemism, we, pumping, fokker,
# Nearest to but: mond, arousal, however, are, unmik, neanderthals, buddhism, exons,
# Nearest to however: shipboard, widespread, entered, muds, certain, but, combines, avenger,
# Nearest to many: some, other, creeping, most, these, stepfather, correspond, attorneys,
# Nearest to if: emirate, dyess, stuck, rehab, demiurge, chd, without, why,
# Nearest to three: four, six, seven, five, eight, two, nine, zero,
# Nearest to on: in, phagspa, with, main, avec, into, embryonic, by,
# Nearest to into: ironically, in, chair, on, from, concubines, unit, rated,
# Nearest to after: banners, laserdisc, syed, implantation, specie, sadat, broadcasts, sutherland,
# Nearest to at: from, sylvia, fondly, in, satirizing, on, for, verhofstadt,
# Nearest to system: genus, starks, tropes, saviola, endings, monopolies, mapsto, yah,
# Nearest to UNK: file, bewitched, dwarfed, barnstorming, jute, breathing, jersey, pinky,

# %%
num_points = 400
tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000) # ValueError: array must not contain infs or NaNs, refer to: https://github.com/scikit-learn/scikit-learn/issues/6665#issuecomment-264029983
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
